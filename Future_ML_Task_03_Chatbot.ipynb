# %%
# !pip install nltk scikit-learn pandas numpy streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 46.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 70.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import nltk
import string

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
data = {
    "question": [
        "How can I reset my password?",
        "I forgot my password",
        "What is your refund policy?",
        "How do I get a refund?",
        "How can I contact customer support?",
        "Is customer care available 24/7?",
        "Where is my order?",
        "Track my order"
    ],
    "intent": [
        "password_reset",
        "password_reset",
        "refund",
        "refund",
        "contact_support",
        "contact_support",
        "order_tracking",
        "order_tracking"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                               question           intent
# 0         How can I reset my password?   password_reset
# 1                 I forgot my password   password_reset
# 2          What is your refund policy?           refund
# 3               How do I get a refund?           refund
# 4  How can I contact customer support?  contact_support
# 5     Is customer care available 24/7?  contact_support
# 6                   Where is my order?   order_tracking
# 7                       Track my order   order_tracking

# %%
def preprocess(text):
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    return text

df["question"] = df["question"].apply(preprocess)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df["question"])
y = df["intent"]

# %%
model = LogisticRegression()
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
responses = {
    "password_reset": "You can reset your password using the 'Forgot Password' option.",
    "refund": "Our refund policy allows refunds within 7 days of purchase.",
    "contact_support": "You can contact support via email or live chat.",
    "order_tracking": "Please enter your order ID to track your order."
}

# %%
def chatbot_reply(user_input):
    user_input = preprocess(user_input)
    vector = vectorizer.transform([user_input])
    intent = model.predict(vector)[0]
    return responses.get(intent, "Sorry, I didn't understand that. Please contact support.")

# %%
while True:
    msg = input("You: ")
    if msg.lower() == "exit":
        print("Bot: Thank you for contacting support!")
        break
    print("Bot:", chatbot_reply(msg))
# Out:
# You: refund
# Bot: Our refund policy allows refunds within 7 days of purchase.
# You: exit
# Bot: Thank you for contacting support!

# %%
# %%writefile app.py
import streamlit as st

st.title("Customer Support Chatbot")

user_input = st.text_input("Ask your question:")

if user_input:
    st.write("Bot:", chatbot_reply(user_input))
# Out:
# Writing app.py
